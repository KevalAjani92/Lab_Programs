# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Lab - 4</b></center>
# <pre>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2

chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Number of Unique Items ?

# %%
chipo["item_name"].nunique()
# Out:
# 50

# %% [markdown]
# ### Step 10. Which was the most-ordered item?

# %%
c = chipo.groupby("item_name")
c = c.sum()
c = c.sort_values(['quantity'],ascending=False)
c[['order_id','quantity']].head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
chipo.groupby("item_name")[['order_id','quantity']].sum().sort_values(by="quantity",ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 11. How many items were orderd in total?

# %%
print(chipo["quantity"].sum())
# Out:
# 4972

# %% [markdown]
# ### Step 12. Turn the item price into a float

# %% [markdown]
# #### Step 12.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 12.b. Create a lambda function and change the type of item price

# %%
float('$2.39 '[1::])
# Out:
# 2.39

# %%
func = lambda x: float(x.replace("$",""))

chipo["item_price"] = chipo["item_price"].apply(func)

# %% [markdown]
# #### Step 12.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity']*chipo['item_price']).sum()
print(f"Revenue was: ${revenue}")
# Out:
# Revenue was: $39237.02

# %% [markdown]
# ### Step 15. How many orders were made ?

# %%
chipo['order_id'].nunique()
# Out:
# 1834

# %% [markdown]
# ### Step 17. How many different choice descriptions are there?

# %%
chipo['choice_description'].nunique()
# Out:
# 1043

# %% [markdown]
# ### Step 18. What items have been ordered more than 100 times?

# %%
items = chipo.groupby('item_name')['quantity'].sum()
items[items>100]
# Out:
# item_name
# Bottled Water                   211
# Canned Soda                     126
# Canned Soft Drink               351
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chicken Salad Bowl              123
# Chicken Soft Tacos              120
# Chips                           230
# Chips and Fresh Tomato Salsa    130
# Chips and Guacamole             506
# Side of Chips                   110
# Steak Bowl                      221
# Steak Burrito                   386
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 19. What is the average revenue amount per order?

# %%
# Solution 1
chipo['item_revenue'] = chipo['quantity']*chipo['item_price']
orderwise_amount = chipo.groupby('order_id')['item_revenue'].sum()
avg_revenue = orderwise_amount.mean()
print(f"Average Revenue Per Order : ${avg_revenue:.2f}")
# Out:
# Average Revenue Per Order : $21.39

# %%
# Solution 2
def func2(x):
    print(x)

chipo.groupby('order_id')[['item_price','quantity']].apply(func2)
# Out:
#    item_price  quantity
# 0        2.39         1
# 1        3.39         1
# 2        3.39         1
# 3        2.39         1
#    item_price  quantity
# 4       16.98         2
#    item_price  quantity
# 5       10.98         1
# 6        1.69         1
#    item_price  quantity
# 7       11.75         1
# 8        9.25         1
#     item_price  quantity
# 9         9.25         1
# 10        4.45         1
#     item_price  quantity
# 11        8.75         1
# 12        8.75         1
#     item_price  quantity
# 13       11.25         1
# 14        4.45         1
#     item_price  quantity
# 15        2.39         1
# 16        8.49         1
#     item_price  quantity
# 17        8.49         1
# 18        2.18         2
#     item_price  quantity
# 19        8.75         1
# 20        4.45         1
#     item_price  quantity
# 21        8.99         1
# 22        3.39         1
#     item_price  quantity
# 23       10.98         1
# 24        3.39         1
# ...

# %%
func1 = lambda x:(x['item_price']*x['quantity']).sum()
mean_val = chipo.groupby('order_id')[['item_price','quantity']].apply(func1).mean()
print(mean_val)
# Out:
# 21.39423118865867
